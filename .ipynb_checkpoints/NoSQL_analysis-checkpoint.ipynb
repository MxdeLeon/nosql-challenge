# %% [markdown]
# # Eat Safe, Love
#
# ## Analysis summary located at end of file.

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
establishments.find_one({})
# Out:
# {'_id': ObjectId('653ec8a1486537027b3b8296'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
# ...

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq':20}}
hyg20 = establishments.find(query)
# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Display the first document in the results using pprint
pprint(hyg20[0], sort_dicts=False)
# Out:
# {'_id': ObjectId('653ec8a1486537027b3b9dc6'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.27694, 'latitude': 50.769705},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
# ...

# %%
# Convert the result to a Pandas DataFrame
df_hyg20 = pd.DataFrame(hyg20)
df_hyg20
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   653ec8a1486537027b3b9dc6   110681                  0
# 1   653ec8a1486537027b3ba14d   612039                  0
# 2   653ec8a1486537027b3ba45f   730933                  0
# 3   653ec8a1486537027b3ba639   172735                  0
# 4   653ec8a1486537027b3ba64d   172953                  0
# 5   653ec8a1486537027b3baff1   512854                  0
# 6   653ec8a1486537027b3bb211  1537089                  0
# 7   653ec8a2486537027b3bc736   155648                  0
# 8   653ec8a2486537027b3bcb85  1012883                  0
# 9   653ec8a2486537027b3bd395   644109                  0
# 10  653ec8a2486537027b3bd408   267034                  0
# 11  653ec8a2486537027b3bdaca   972876                  0
# 12  653ec8a2486537027b3be37d  1417416                  0
# 13  653ec8a2486537027b3be994  1384371                  0
# 14  653ec8a2486537027b3beced   907216                  0
# ...

# %%
# Display the number of rows in the DataFrame
print(df_hyg20.index.size)
# Display the first 10 rows of the DataFrame
df_hyg20.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  653ec8a1486537027b3b9dc6   110681                  0
# 1  653ec8a1486537027b3ba14d   612039                  0
# 2  653ec8a1486537027b3ba45f   730933                  0
# 3  653ec8a1486537027b3ba639   172735                  0
# 4  653ec8a1486537027b3ba64d   172953                  0
# 5  653ec8a1486537027b3baff1   512854                  0
# 6  653ec8a1486537027b3bb211  1537089                  0
# 7  653ec8a2486537027b3bc736   155648                  0
# 8  653ec8a2486537027b3bcb85  1012883                  0
# 9  653ec8a2486537027b3bd395   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %%
establishments.find_one({})
# Out:
# {'_id': ObjectId('653ec8a1486537027b3b8296'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName':{'$regex':'London'}, 'RatingValue':{'$gte':4}}

london4 = establishments.find(query)

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Display the first document in the results using pprint
pprint(london4[0], sort_dicts=False)
# Out:
# {'_id': ObjectId('653ec8a1486537027b3bb7e1'),
#  'FHRSID': 621707,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'PostCode': 'ME12',
#  'Phone': '',
#  'RatingValue': 4,
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2021-10-18T00:00:00',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.508551, 'latitude': 51.369321},
#  'RightToReply': '',
#  'Distance': 4627.439467780196,
# ...

# %%
# Convert the result to a Pandas DataFrame
df_london4 = pd.DataFrame(london4)
# Display the number of rows in the DataFrame
print(df_london4.index.size)
# Display the first 10 rows of the DataFrame
df_london4.head(10)
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  653ec8a1486537027b3bb7e1   621707                  0
# 1  653ec8a2486537027b3bbb03  1130836                  0
# 2  653ec8a2486537027b3bc657   293783                  0
# 3  653ec8a2486537027b3bd455   294474                  0
# 4  653ec8a2486537027b3bd457  1315095                  0
# 5  653ec8a2486537027b3bdb67   294900                  0
# 6  653ec8a2486537027b3bfc68   293756                  0
# 7  653ec8a2486537027b3c0031   878523                  0
# 8  653ec8a2486537027b3c004a   293772                  0
# 9  653ec8a2486537027b3c004b   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = (establishments.find({'BusinessName':'Penang Flavours'}, {'geocode.latitude':1}))[0]['geocode']['latitude']
longitude = (establishments.find({'BusinessName':'Penang Flavours'}, {'geocode.longitude':1}))[0]['geocode']['longitude']

query = {'$and':[{'geocode.latitude':{'$lte':(latitude+degree_search)}},
                 {'geocode.latitude':{'$gte':(latitude-degree_search)}},
                 {'geocode.longitude':{'$lte':(longitude+degree_search)}},
                 {'geocode.longitude':{'$gte':(longitude-degree_search)}},
                 {'RatingValue':{'$eq':5}}
                ]
        }

near_pen = establishments.find(query).sort('scores.Hygiene')
near_pen = list(near_pen)
# Print the results

for val in near_pen:
    pprint(val, sort_dicts=False)
# Out:
# {'_id': ObjectId('653ec8a2486537027b3bf601'),
#  'FHRSID': 695223,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000178842',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'PostCode': 'SE18 1JQ',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2019-11-13T00:00:00',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.0924199968576431, 'latitude': 51.4871482849121},
#  'RightToReply': '',
#  'Distance': 4646.946071297699,
# ...

# %%
# Convert result to Pandas DataFrame
df_near_pen = pd.DataFrame(near_pen)
df_near_pen.head(5)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  653ec8a2486537027b3bf601   695223                  0
# 1  653ec8a2486537027b3bf60a  1380578                  0
# 2  653ec8a2486537027b3bf62c   694609                  0
# 3  653ec8a2486537027b3bf63d   909912                  0
# 4  653ec8a2486537027b3bf63f   694478                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000178842                              Iceland
# 1                    14425  Howe and Co Fish and Chips - Van 17
# 2             PI/000116619                            Volunteer
# 3             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 4             PI/000086506                    Atlantic Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0  Retailers - supermarkets/hypermarkets            7840
# 1                         Mobile caterer            7846
# 2                      Pub/bar/nightclub            7843
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene': {'$eq':0}}}

group_query = {'$group': {'_id':'$LocalAuthorityName', 'count': {'$sum':1}}}

sort_values = {'$sort': {'count': -1}}

pipeline = [match_query, group_query, sort_values]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result

print(len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df_hygiene = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(df_hygiene.index.size)
# Display the first 10 rows of the DataFrame
df_hygiene.head(10)
# Out:
# 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542

# %% [markdown]
# # Analysis
#
# ## There are 41 establishments with a hygiene score of 20.
# ## The first 10 are:
# ![image.png](attachment:image.png)
#
# ## There are 33 establishments with a Rating Value higher than 3.
# ## The first 10 are:
# ![image-2.png](attachment:image-2.png)
#
# ## The top 5 establishments, sorted by hygiene score, near Penang Flavours are:
# ![image-3.png](attachment:image-3.png)
#
# ## Counts of establishments with a hygiene score of 0 (Best score possible), by local authority:
# ![image-4.png](attachment:image-4.png)
